# %%
#Importing libraries
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re
import numpy as np

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}

# %% [markdown]
# ### Scraping Fridges data
#
# In this process, we are scraping fridge product data from the Kilimall site. The data is then cleaned by handling missing values, removing duplicates, and standardizing the format for consistency. This ensures that the dataset is accurate, structured, and ready for analysis or further processing.

# %%
# getting data with product link
fridges_links = []

for x in range(1,17):
    result = requests.get(f"https://www.kilimall.co.ke/search?q=FRIDGE&page={x}&source=search|enterSearch|FRIDGE",headers=headers)
    soup = BeautifulSoup(result.content, "html.parser")
    fridges_list = soup.find_all("div", class_ = "product-item")

    for fridges in fridges_list:
        for link in fridges.find_all("a", href = True):
            fridges_links.append("https://www.kilimall.co.ke" + link["href"])

# %%
# Initialize a list to store all fridges data
fridges = []

# Loop through all 16 pages
for x in range(1, 17):  # Pages 1 to 16
    print(f"Scraping page {x}...")
    
    # Send a GET request to the page
    result = requests.get(f'https://www.kilimall.co.ke/search?q=FRIDGE&page={x}&source=search|enterSearch|FRIDGE', headers=headers)
    
    # Check if the request was successful
    if result.status_code == 200:
        soup = BeautifulSoup(result.text, 'html.parser')  # Parse the HTML content
        
        # Extract fridge details from divs with the class "info-box".
        fridges_info = soup.find_all('div', class_="info-box")
        
        # Extract relevant details
        for fridge_info in fridges_info:
            # Safely extract data, handle cases where tags are missing
            fridge_name = fridge_info.find('p', class_='product-title')
            fridge_price = fridge_info.find('div', class_='product-price')
            fridge_reviews = fridge_info.find('span', class_='reviews')
            
            # Clean and append extracted data
            fridges.append({
                "Name": fridge_name.text.strip() if fridge_name else "N/A",
                "Price": fridge_price.text.strip() if fridge_price else "N/A",
                "Reviews": fridge_reviews.text.strip() if fridge_reviews else "N/A"
            })
    else:
        print(f"Failed to fetch page {x}, Status code: {result.status_code}")
# Out:
# Scraping page 1...
# Scraping page 2...
# Scraping page 3...
# Scraping page 4...
# Scraping page 5...
# Scraping page 6...
# Scraping page 7...
# Scraping page 8...
# Scraping page 9...
# Scraping page 10...
# Scraping page 11...
# Scraping page 12...
# Scraping page 13...
# Scraping page 14...
# Scraping page 15...
# Scraping page 16...

# %%
#Save results as a DataFrame
df_fridges = pd.DataFrame(fridges)
df_fridges["Links"] = fridges_links
df_fridges.sample(20)
# Out:
#                                                   Name        Price Reviews  \
# 566  Heavy Duty Fridge Stand Washing machine Cooker...    KSh 3,698     (0)
# 557  7.5L Car Refrigerator, Hot And Cold Mini Car F...    KSh 5,159     (0)
# 435  Hisense Fridge 91 Liters Double Door+2 YEARS W...   KSh 26,599     (0)
# 86   Ramtons RF/244 -2 Door Direct Cool Fridge- 213...   KSh 47,999     (1)
# 530        Portable Mini Car Fridge Cooler Warmer 7.5L    KSh 4,499     (0)
# 399                 Mika 211 Litres Double Door Fridge   KSh 56,025     (0)
# 154       Mika MRDCS92DS,92L - Single Door Mini Fridge   KSh 24,500     (0)
# 164  Ramtons RF/130- 213L 2 Door Direct Cool Fridge...   KSh 51,300     (0)
# 95   Mika Fridge, 202L, 2 Door Top Mount Freezer, N...   KSh 59,999     (0)
# 400  NUNIX 138L BCD-138 Fridge Double Door Direct C...   KSh 33,999     (0)
# 367        Ramtons RF/223-93 Litres Single Door Fridge   KSh 31,235     (0)
# 296  Premier QUALITY PM-90L Fridge Single Door As T...   KSh 21,999     (0)
# 227  (LIMITED OFFER) LG fridge Semi Auto Defrost Sm...   KSh 67,699     (0)
# 376                     Roch 90ltrs Single Door Fridge   KSh 25,000     (0)
# 52   Ramtons RF/319- 430 LITERS SIDE BY SIDE LED NO...  KSh 104,900     (0)
# 215  Ramtons 378 LITRES DOUBLE DOOR NO FROST FRIDGE...   KSh 99,999     (0)
# 402  Premier 90L SINGLE DOOR FRIDGE Single Door Ref...   KSh 45,200     (0)
# 129  Fridge, Double Door , 170L - Silver, SFR-210-D...   KSh 39,999     (0)
# 354  [TOP SALE ] HISENSE Fridge 92L, Direct Cool, S...   KSh 23,999     (0)
# 484            Royal Double Door 125L Fridge - RF-130D   KSh 39,895     (0)
#
#                                                  Links
# 566  https://www.kilimall.co.ke/listing/1000153670-...
# 557  https://www.kilimall.co.ke/listing/1000282976-...
# 435  https://www.kilimall.co.ke/listing/1000080955-...
# 86   https://www.kilimall.co.ke/listing/2563201-ram...
# 530  https://www.kilimall.co.ke/listing/1001017095-...
# 399  https://www.kilimall.co.ke/listing/1000276509-...
# 154  https://www.kilimall.co.ke/listing/1001032104-...
# 164  https://www.kilimall.co.ke/listing/1000422672-...
# 95   https://www.kilimall.co.ke/listing/1001015266-...
# 400  https://www.kilimall.co.ke/listing/1000074739-...
# 367  https://www.kilimall.co.ke/listing/2708219-ram...
# 296  https://www.kilimall.co.ke/listing/2748494-pre...
# 227  https://www.kilimall.co.ke/listing/2996373-lim...
# 376  https://www.kilimall.co.ke/listing/2629194-roc...
# 52   https://www.kilimall.co.ke/listing/1001009332-...
# 215  https://www.kilimall.co.ke/listing/1000085913-...
# 402  https://www.kilimall.co.ke/listing/2940620-pre...
# 129  https://www.kilimall.co.ke/listing/1000442292-...
# 354  https://www.kilimall.co.ke/listing/2964768-his...
# 484  https://www.kilimall.co.ke/listing/1000221012-...

# %%
df_fridges.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 566 entries, 0 to 565
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     566 non-null    object
#  1   Price    566 non-null    object
#  2   Reviews  566 non-null    object
#  3   Links    566 non-null    object
# dtypes: object(4)
# memory usage: 17.8+ KB

# %% [markdown]
# ##### Data cleaning

# %%
# Function to clean the product name
def clean_name(name):
    
    # Remove words in parentheses or curly brackets if they contain "offer", "offers", "sale", or "sales"
    name = re.sub(r'\(([^)]*?(OFFER|OFFERS|SALE|SALES)[^)]*?)\)', '', name, flags=re.IGNORECASE)
    name = re.sub(r'\{([^}]*?(OFFER|OFFERS|SALE|SALES)[^}]*?)\}', '', name, flags=re.IGNORECASE)

    # Remove variations of "offer" and "sale" (including "offers", "sales")
    name = re.sub(r'\b(\w+)\s+(OFFER|OFFERS|SALE|SALES)\b', '', name, flags=re.IGNORECASE)
    
    # Remove unnecessary marketing phrases
    name = re.sub(r'\b(BLACK FRIDAY|BLACK FRIDAY OFFERS|BEST DEALS|LIMITED|LIMITED TIME|TECH WEEK|OFFER|BEST WHOLESALE PRICE|SPECIAL OFFERS)\b', '', name, flags=re.IGNORECASE)
    
    # Remove all remaining parentheses, curly braces, brackets, and clean extra spaces
    name = re.sub(r'[\(\)\{\}\[\]]', '', name)  # Remove parentheses, braces, and brackets
    name = re.sub(r'\s+', ' ', name)  # Replace multiple spaces with a single space
    
    # Remove special characters like '!', '+' if they appear as the first word
    name = re.sub(r'^[!+\[\]]+', '', name).strip()  # Strip unwanted characters at the start
    
    # Remove emojis using a regex for unicode emoji ranges
    name = re.sub(r'[^\w\s,.-]', '', name)  # Remove non-alphanumeric characters (including emojis)

    # Final trim to remove leading/trailing spaces
    name = name.strip()
    
    return name

# Apply the cleaning function to the 'Name' column in the DataFrame

df_fridges['Name'] = df_fridges['Name'].apply(clean_name)

# %%
#Remove commas and any text from Price column
df_fridges["Price"] = df_fridges['Price'].str.replace(r'[^\d]', '', regex=True)
# Rename the Price column
df_fridges = df_fridges.rename(columns={'Price': 'Price(kshs)'})



#Remove brackets from Reviews column
df_fridges['Reviews'] = df_fridges['Reviews'].str.extract(r'(\d+)')
df_fridges.sample(20)
# Out:
#                                                   Name Price(kshs) Reviews  \
# 475  Original Low energy consumption Rebune Fridge ...       51500       0
# 130  Volsmart 108L Double Door Fridge With A Larger...       26055       0
# 211   Roch RFR-190S-I Single Door Fridge - 150 Litresr       35999       1
# 41   SmartPro 138 Litres Refrigerator SFR-175-DT-I ...       31399       2
# 40   Ramtons 90 LITRES DOUBLE DOOR DIRECT COOL FRID...       26999      34
# 273  RAMTONS 128 LITERS 2 DOOR DIRECT COOL FRIDGE, ...       37800       0
# 112  RESTOCKED Efficient Cooling for Your Kitchen N...       24200       0
# 93   Mika Fridge, 202L, 2 Door Top Mount Freezer, N...       59999       0
# 305  Hisense RS-12DR4SA 92L Single Door Direct Cool...       25999       0
# 522  1 Mika fridge of 202L No frost  FREE 1 JSB Ext...       60000       0
# 219  LG Inverter linear compressor Fridge GC-J257SQ...      359119       0
# 406              94 LITRES TEXTEND AND APPROVED FRIDGE       34850       0
# 67   Nunix 138L BCD-138 fridge double door Direct C...       29999       0
# 409             320 LITRES DOUBLE DOOR FRIDGE NO FROST      126500       0
# 109  Hisense REF094DR - 94L Single Door Fridge2 YEA...       24899       0
# 217           Beko Single Door Fridge  198Ltrs BAS598X       39999       0
# 28   Roch RFR-150-DT-I 118L Double Door Refrigerato...       28749      31
# 53   MIKA MRDCD168DS 168L, 2 Door Top Mount Freezer...       36999       0
# 241  Hisense 92L Single Door Direct Cooling Fridge,...       24999       0
# 365          Royal - RF-230D Double Door Fridge - 206L       42275       0
#
#                                                  Links
# 475  https://www.kilimall.co.ke/listing/2594830-ori...
# 130  https://www.kilimall.co.ke/listing/1000448749-...
# 211  https://www.kilimall.co.ke/listing/1000196641-...
# 41   https://www.kilimall.co.ke/listing/1000360077-...
# 40   https://www.kilimall.co.ke/listing/2541784-ram...
# 273  https://www.kilimall.co.ke/listing/3029960-ram...
# 112  https://www.kilimall.co.ke/listing/1001037989-...
# 93   https://www.kilimall.co.ke/listing/1001015266-...
# 305  https://www.kilimall.co.ke/listing/2760888-his...
# 522  https://www.kilimall.co.ke/listing/1000398910-...
# 219  https://www.kilimall.co.ke/listing/2721784-lim...
# 406  https://www.kilimall.co.ke/listing/2977024-320...
# 67   https://www.kilimall.co.ke/listing/1000397088-...
# 409  https://www.kilimall.co.ke/listing/2978206-120...
# 109  https://www.kilimall.co.ke/listing/1000427233-...
# 217  https://www.kilimall.co.ke/listing/2964782-bek...
# 28   https://www.kilimall.co.ke/listing/2748705-roc...
# 53   https://www.kilimall.co.ke/listing/1001002585-...
# 241  https://www.kilimall.co.ke/listing/2464210-his...
# 365  https://www.kilimall.co.ke/listing/3075628-roy...

# %% [markdown]
# ##### Remove duplicates

# %%
#Checking how many duplicates
duplicate_count = int(df_fridges.duplicated( keep=False).sum())
print(f"There are {duplicate_count} duplicates")

#Find all duplicates
duplicates = df_fridges[df_fridges.duplicated( keep=False)]
duplicates
# Out:
# There are 0 duplicates
# Empty DataFrame
# Columns: [Name, Price(kshs), Reviews, Links]
# Index: []

# %%
# Remove duplicates, keeping the first occurrence
df_fridges = df_fridges.drop_duplicates()

# %% [markdown]
# ##### Feature Extraction

# %%
# Extract the number of doors
def extract_doors(description):
    # Define the regex pattern to match numbers/keywords before "Door" or "Doors"
    pattern = r'\b(1|one|2|two|3|three|4|four|Single|Double)\b(?:\s*Doors)?'
    # Search for the pattern in the description
    match = re.search(pattern, description, re.IGNORECASE)
    # Map matches to corresponding numeric values
    door_mapping = {
        "1": 1,
        "one": 1,
        "single": 1,
        "2": 2,
        "two": 2,
        "double": 2,
        "4": 4,
        "four": 4}
    if match:
        door_type = match.group(1).lower()  # Convert the match to lowercase
        return door_mapping.get(door_type, "Unknown")  # Map to the number of doors
    return "Unknown"  # If no match is found



# Extract capacity in litres
def extract_capacity(description):
    # Define the regex pattern
    pattern = r'(\d+(\.\d+)?)\s*(L|litres|ltrs|lt)'
    # Search for the pattern in the description
    match = re.search(pattern, description, re.IGNORECASE)
    if match:
        return float(match.group(1))  # Return the number as float
    return None  # Return None if no match is found




#Extract brand names
brands = ['Volsmart','Hisense','Roch','Nunnix','Smartpro','Nunix','Ecomax','Ramtons','Mika','Von','Haier','Exzel','GLD','Vitron','Smartpro','Bruhm','Premier','Samsung', 'Ailyons', 'LG', 'Solstar', 'Royal','Beko','Syinix','ICECOOL','Rebune','Legacy','FK','Smart pro']
# Function to extract the brand name
def extract_brand(product_name):
    for brand in brands:
        if brand.lower() in product_name.lower():  # Case insensitive match
            return brand
    return 'Unknown'  # Return 'Unknown' if no brand is found





# Apply the extraction functions to the DataFrame
df_fridges["Doors"] = df_fridges["Name"].apply(extract_doors)
df_fridges['Capacity(ltrs)'] = df_fridges['Name'].apply(extract_capacity)
df_fridges['Brand'] = df_fridges['Name'].apply(extract_brand)


# Display the updated DataFrame
df_fridges.sample(20)
# Out:
#                                                   Name Price(kshs) Reviews  \
# 24   MIKA Fridge, 138L, 2 Door Top Mount Freezer, D...       35500       0
# 290  VOLSMART 118L Fridge Freezer Energy Saving Dou...       29430       0
# 145           NUNIX ModelBC-92 Direct Cool Fridge  92L       21000       0
# 298  Exzel Fridge 515L No Frost ERFF-515SL, Inverte...      101978       0
# 379  Nunix 138L Double Door Fridge Energy Efficient...       30499       0
# 71   Nunix 92L Single Door Fridge Energy Efficient ...       23999       0
# 335          DEAL Hisense Fridge 91 Liters Double Door       24999       0
# 172  LG Freezer Fridge 287L smart inverter with 1 y...       96699       0
# 103  MIKA Fridge, 168L, 2 Door Top Mount Freezer, D...       45800       0
# 442          Royal - RF-195D Double Door Fridge - 181L       49995       0
# 524  7.5litre Portable car fridge, Made of premium ...        3776       0
# 199               Hisense 94 Litres Single Door Fridge       27649       0
# 278  PRICE DROP Nunix 138L Large Capacity Double Do...       29950       0
# 142               Von Hotpoint 134L Double Door Fridge       35000       0
# 241  Hisense 92L Single Door Direct Cooling Fridge,...       24999       0
# 70   Von Tropicalised compressor VARM-11DHS Mini Fr...       26199       5
# 61   Ailyons Mini Double Door Direct Cool Fridge- 1...       26000       0
# 434  Roch RFR-110D-B Double Door Refrigerator - 85 ...       25650       0
# 121  Premier 128 Litres Double Door Fridge - Silver...       28700       0
# 286  Hisense 94L Single Door Fridge  REF094DR2 YEAR...       24999       0
#
#                                                  Links    Doors  \
# 24   https://www.kilimall.co.ke/listing/1000339776-...        2
# 290  https://www.kilimall.co.ke/listing/1000349863-...        2
# 145  https://www.kilimall.co.ke/listing/1001015971-...  Unknown
# 298  https://www.kilimall.co.ke/listing/1000348165-...        2
# 379  https://www.kilimall.co.ke/listing/1000257887-...        2
# 71   https://www.kilimall.co.ke/listing/1001027581-...        1
# 335  https://www.kilimall.co.ke/listing/2979451-bla...        2
# 172  https://www.kilimall.co.ke/listing/3036626-lg-...        1
# 103  https://www.kilimall.co.ke/listing/1000447214-...        2
# 442  https://www.kilimall.co.ke/listing/1000221955-...        2
# 524  https://www.kilimall.co.ke/listing/1001017262-...  Unknown
# 199  https://www.kilimall.co.ke/listing/1000373234-...        1
# 278  https://www.kilimall.co.ke/listing/1000132360-...        2
# 142  https://www.kilimall.co.ke/listing/1000440821-...        2
# 241  https://www.kilimall.co.ke/listing/2464210-his...        1
# 70   https://www.kilimall.co.ke/listing/2263898-von...        1
# 61   https://www.kilimall.co.ke/listing/1000409833-...        2
# 434  https://www.kilimall.co.ke/listing/1000120788-...        2
# 121  https://www.kilimall.co.ke/listing/1000434745-...        2
# 286  https://www.kilimall.co.ke/listing/1000361300-...        1
#
#      Capacity(ltrs)     Brand
# 24            138.0      Mika
# 290           118.0  Volsmart
# 145            92.0     Nunix
# 298           515.0     Exzel
# 379           138.0     Nunix
# 71             92.0     Nunix
# 335            91.0   Hisense
# 172           287.0        LG
# 103           168.0      Mika
# 442           181.0     Royal
# 524             7.5   Unknown
# 199            94.0   Hisense
# 278           138.0     Nunix
# 142           134.0       Von
# 241            92.0   Hisense
# 70             90.0       Von
# 61            115.0   Ailyons
# 434            85.0      Roch
# 121           128.0   Premier
# 286            94.0   Hisense

# %%
# Standardize brand names (replace "Smart Pro" with "Smartpro")
df_fridges['Brand'] = df_fridges['Brand'].replace({'Smart pro': 'Smartpro','Nunnix': 'Nunix'})
df_fridges['Brand'].value_counts()
# Out:
# Brand
# Ramtons     91
# Mika        84
# Hisense     67
# Unknown     58
# Von         47
# Nunix       46
# Volsmart    27
# Roch        26
# Premier     18
# Haier       18
# LG          13
# Exzel       10
# Rebune       8
# Ecomax       7
# Royal        7
# Smartpro     6
# Vitron       6
# Beko         5
# Solstar      5
# Syinix       5
# GLD          3
# Ailyons      3
# FK           3
# Samsung      1
# ICECOOL      1
# Legacy       1
# Name: count, dtype: int64

# %%
# Save to CSV
#df_fridges.to_csv('csv_files/kilimall_clean_fridges.csv', index=True)

# %% [markdown]
# ### Scraping Laptops data

# %%
# Initialize a list to store all laptops' data
laptops = []

# Loop through all 90 pages
for x in range(1, 91):  # Pages 1 to 90
    print(f"Scraping page {x}...")
    
    # Send a GET request to the page
    result = requests.get(f'https://www.kilimall.co.ke/search?q=laptop&page={x}&source=search|enterSearch|laptop',headers=headers)
    
    # Check if the request was successful
    if result.status_code == 200:
        soup = BeautifulSoup(result.text, 'html.parser')  # Parse the HTML content
        
        # Extract laptop details from divs with the class "info-box".
        laptops_info = soup.find_all('div', class_="info-box")
        
        # Extract relevant details
        for laptop_info in laptops_info:
            # Safely extract data, handle cases where tags are missing
            laptop_name = laptop_info.find('p', class_='product-title')
            laptop_price = laptop_info.find('div', class_='product-price')
            laptop_reviews = laptop_info.find('span', class_='reviews')
            
            # Clean and append extracted data
            laptops.append({
                "Name": laptop_name.text.strip() if laptop_name else "N/A",
                "Price": laptop_price.text.strip() if laptop_price else "N/A",
                "Reviews": laptop_reviews.text.strip() if laptop_reviews else "N/A"
            })
    else:
        print(f"Failed to fetch page {x}, Status code: {result.status_code}")
# Out:
# Scraping page 1...
# Scraping page 2...
# Scraping page 3...
# Scraping page 4...
# Scraping page 5...
# Scraping page 6...
# Scraping page 7...
# Scraping page 8...
# Scraping page 9...
# Scraping page 10...
# Scraping page 11...
# Scraping page 12...
# Scraping page 13...
# Scraping page 14...
# Scraping page 15...
# Scraping page 16...
# Scraping page 17...
# Scraping page 18...
# Scraping page 19...
# Scraping page 20...
# Scraping page 21...
# Scraping page 22...
# Scraping page 23...
# Scraping page 24...
# Scraping page 25...
# Scraping page 26...
# Scraping page 27...
# Scraping page 28...
# Scraping page 29...
# Scraping page 30...
# Scraping page 31...
# Scraping page 32...
# Scraping page 33...
# Scraping page 34...
# Scraping page 35...
# Scraping page 36...
# Scraping page 37...
# Scraping page 38...
# Scraping page 39...
# Scraping page 40...
# Scraping page 41...
# Scraping page 42...
# Scraping page 43...
# Scraping page 44...
# Scraping page 45...
# Scraping page 46...
# Scraping page 47...
# Scraping page 48...
# Scraping page 49...
# Scraping page 50...
# Scraping page 51...
# Scraping page 52...
# Scraping page 53...
# Scraping page 54...
# Scraping page 55...
# Scraping page 56...
# Scraping page 57...
# Scraping page 58...
# Scraping page 59...
# Scraping page 60...
# Scraping page 61...
# Scraping page 62...
# Scraping page 63...
# Scraping page 64...
# Scraping page 65...
# Scraping page 66...
# Scraping page 67...
# Scraping page 68...
# Scraping page 69...
# Scraping page 70...
# Scraping page 71...
# Scraping page 72...
# Scraping page 73...
# Scraping page 74...
# Scraping page 75...
# Scraping page 76...
# Scraping page 77...
# Scraping page 78...
# Scraping page 79...
# Scraping page 80...
# Scraping page 81...
# Scraping page 82...
# Scraping page 83...
# Scraping page 84...
# Scraping page 85...
# Scraping page 86...
# Scraping page 87...
# Scraping page 88...
# Scraping page 89...
# Scraping page 90...

# %%
# Set the maximum number of rows and columns to display
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns

# %%
#Save results as a DataFrame
df_laptops = pd.DataFrame(laptops)
df_laptops.sample(20)
# Out:
#                                                    Name       Price Reviews
# 232   REFURBISHED Dell Latitude 7300 Business Laptop...  KSh 24,999     (0)
# 2083  (LIMITED SPECIAL OFFER) REFURBISHED LENOVO THI...  KSh 14,499     (0)
# 2833  HP EliteBook 830 G5 Intel Core i5 8th Gen 16GB...  KSh 44,000     (0)
# 1688  HP ELITEBOOK 820 G3 6TH GEN COREi5 8GB RAM 256...  KSh 20,999     (0)
# 1354           Lenovo x260 Core i5 8GB 256GB SSD Laptop  KSh 25,500     (0)
# 2038  Lenovo ThinkPad X260 Intel Core I5, 8GB RAM, 2...  KSh 28,500     (2)
# 2103  (SPECIAL OFFER) DELL LATITUDE E7470| CORE I5| ...  KSh 25,499     (1)
# 1979  All In One Imac 17,1 Intel Core i5 6th Gen 3.2...  KSh 65,250     (0)
# 2486  (RBEST OFFER) DELL LATITUDE 5570 INTEL CORE i5...  KSh 23,000     (0)
# 1258  (special offer) Refurbished laptop Computer hp...  KSh 18,599     (0)
# 2473  HP EliteBook x360 1030 G4 Intel Core i7 8th Ge...  KSh 75,000     (0)
# 334   Refurbished HP EliteBook 840 G3 8GB RAM 256GB ...  KSh 30,000     (0)
# 2799                Hp 830 g5 corei5 8gb 256ssd 8th Gen  KSh 35,000     (0)
# 1546  Lenovo x390 Yoga Core I5 8th Generation 16GB +...  KSh 32,999     (0)
# 1576  {VERY CLEAN} DELL LATITUDE E7440 INTEL CORE i7...  KSh 18,499     (0)
# 1013  [SUPER BRANDS SALE] HP Elitebook 8460 Laptop C...  KSh 19,000     (0)
# 2500  Hp ProBook 450 G5 Intel(R) Core(TM) i5 8th Gen...  KSh 43,400     (0)
# 2010  Lenovo Ideapad 3-15.6"-Intel Celeron-1TB HDD-4...  KSh 35,699     (0)
# 15    Refurbished Macbook Air 2015 Silver 13 inch ap...  KSh 32,500     (1)
# 394   Offer Refurbished HP EliteBook 830 G6 X360 cor...  KSh 48,999     (0)

# %% [markdown]
# #### Data Cleaning and feature extraction

# %%
# Extract the screen size (integer or float)
def extract_screen_size(description):
    # Regex to capture floats/integers before "inch", "inches", or `"`
    match = re.search(r"(\d+\.\d+|\d+)(?=\s*(?:''|\"|inch|inches?))", description, re.IGNORECASE)
    # If a match is found, return the captured number
    # Regex to capture floats/integers directly before `"`
    match_quote = re.search(r'(\d+\.?\d*)\s*(?=")', description)
    if match:
        return float(match.group(1))  # Return match before "inch" or "inches"
    elif match_quote:
        return match_quote.group(1)  # Return match with `"`
    else:
        return np.nan  # Return NaN if no match is found
    


# Extract RAM
def extract_ram(name):
    match = re.search(r'(\d+)\s*GB\s*RAM', name, re.IGNORECASE)  # Adjust regex to allow flexible spacing
    return f"{match.group(1)}GB" if match else 'Unknown'  # Return the RAM size with "GB" appended




# extract ROM with or without SSD/HDD
def extract_rom(name):
    # Define the regex pattern to capture storage sizes (with or without space) and optional SSD/HDD
    pattern = r'\b(128\s*GB|256\s*GB|250\s*GB|320\s*GB|500\s*GB|512\s*GB|750\s*GB|1000\s*GB|1\s*TB|2\s*TB)\b(?:\s*(HDD|SSD|BROM|Storage))?'
    # Search for a match
    match = re.search(pattern, name, re.IGNORECASE) 
    if match:
        # Extract the size and optional type
        size = match.group(1).replace(' ', '').upper()  
        storage_type = match.group(2).upper() if match.group(2) else ""  # Get the type if it exists
        return f"{size} {storage_type}".strip()  # Combine size and type, removing extra spaces
    else:
        return 'Unknown'  # Default if no match found


# Extract processor model and append "Intel Core" before it
def extract_processor(name):
    # Define a regex pattern to capture only the processor model (i3, i5, i7, i9)
    pattern = r'\b(i[3-9])\b'  # Match i3, i5, i7, i9 with word boundaries
    match = re.search(pattern, name, re.IGNORECASE)
    if match:
        processor_model = match.group(0).lower()  # Extract the processor model (i3, i5, i7, i9)
        return f"Intel Core {processor_model}"  # Prepend "Intel Core" to the processor model
    else:
        return 'Unknown'  # Return 'Unknown' if no valid processor is found



# Extract brand names
brands = [
    "Lenovo", "HP", "MacBook", "NEC", "Panasonic", "Asus", "Dell", "FUJITSU", "Toshiba", "Infinix", "Microsoft Surface","Chuwi","Sony","Acer","GPD"]
# Create a regex pattern to match the brand names
pattern = r'\b(?:' + '|'.join(re.escape(brand) for brand in brands) + r')\b'
# Find all brand names 
def find_brand(name):
    match = re.search(pattern, name, re.IGNORECASE)
    return next((brand for brand in brands if brand.lower() == match.group(0).lower()), "Unknown") if match else "Unknown"



# Apply the extraction/cleaning functions to the DataFrame
df_laptops['Name'] = df_laptops['Name'].apply(clean_name)
df_laptops['Screen_size'] = df_laptops['Name'].apply(extract_screen_size)
df_laptops['RAM']=df_laptops['Name'].apply(extract_ram)
df_laptops['ROM'] =df_laptops['Name'].apply(extract_rom)
df_laptops['Processor'] = df_laptops['Name'].apply(extract_processor)
df_laptops['Brand'] = df_laptops['Name'].apply(find_brand)

# %%
# Define the combined function to clean and extract RAM
def clean_and_extract_ram(row):
    # Step 1: Clean the RAM value if it contains 58GB, 78GB, 116GB, 716GB, or 516GB
    row['RAM'] = re.sub(r'\b(58GB|78GB)\b', '8GB', row['RAM'])  # Replace 58 GB and 78 GB with 8GB
    row['RAM'] = re.sub(r'\b(116GB|716GB|516GB)\b', '16GB', row['RAM'])  # Replace 116gb, 716gb, 516gb with 16gb

    # Step 2: If RAM is unknown, extract the valid RAM value from the 'Name' column
    if row['RAM'] == "Unknown":  # Only process if the RAM is unknown
        # Define the RAM pattern (limited to 4GB, 8GB, 16GB, 32GB, 64GB)
        ram_pattern = r'\b(4|8|16|32|64)\s*GB'
        # Attempt to find the RAM in the 'Name' field
        match = re.findall(ram_pattern, row['Name'])
        if match:
            # Return the first match found (assuming we want just the first match)
            row['RAM'] = match[0] + "GB"  # Append 'GB' to match

    return row['RAM']

# Apply the combined function across the DataFrame
df_laptops['RAM'] = df_laptops.apply(clean_and_extract_ram, axis=1)

# %%
#Extract brand name (special cases)
special_cases = {"yoga": "Lenovo", 
                 "elitebook": "HP", 
                 "probook": "HP", 
                 "spectre": "HP",
                 "iMAC":"Macbook",
                 "Mackbook":"Macbook",
                 "Thinkpad":"Lenovo",
                 "Latitude":"Dell"}

def find_brand(name, current_value):
    if current_value != "Unknown":
        return current_value
    return next((brand for keyword, brand in special_cases.items() if keyword.lower() in name.lower()), "Unknown")
# Apply the function only to rows with 'Unknown' in the 'Brand' column
df_laptops['Brand'] = df_laptops.apply(lambda row: find_brand(row['Name'], row['Brand']), axis=1)

# %%
df_laptops["Brand"].value_counts()
# Out:
# Brand
# HP                   1605
# Lenovo                786
# Dell                  378
# MacBook                53
# Unknown                17
# Asus                   16
# Toshiba                12
# Microsoft Surface       9
# NEC                     7
# FUJITSU                 7
# Macbook                 6
# Acer                    6
# Panasonic               4
#  Chuwi                  4
# Sony                    2
# Infinix                 2
# GPD                     1
# Name: count, dtype: int64

# %%
# using pd.set_option() to widen the output display
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %%
df_laptops[df_laptops['RAM']=="64GB"]
# Out:
#                                                                                                                                                                                          Name  \
# 385  GAMING LAPTOP DELL PRECISION 15 5550 10TH GE INTEL CORE i9 64GB RAM 512GB SSD 4GB DEDICATED GRAPHICS CARD NVIDIA TOUCHSCREEN LAPTOP,15INCHES NOTEBOOK ,REFURBISHED COMPUTERFREE BAGMOUSE
#
#            Price Reviews  Screen_size   RAM        ROM      Processor Brand
# 385  KSh 105,999     (0)         15.0  64GB  512GB SSD  Intel Core i9  DELL

# %%
df_laptops["ROM"].value_counts()
# Out:
# ROM
# 256GB SSD        1062
# 500GB HDD         555
# Unknown           504
# 128GB SSD         210
# 512GB SSD         188
# 500GB             137
# 256GB              86
# 1TB HDD            28
# 128GB              23
# 512GB              21
# 320GB HDD          19
# 1TB SSD            16
# 500GB SSD          15
# 1TB                 9
# 750GB HDD           7
# 500GB STORAGE       6
# 320GB               5
# 256GB HDD           5
# 256GB STORAGE       4
# 1000GB              2
# 512GB STORAGE       2
# 250GB HDD           2
# 512GB HDD           2
# 128GB HDD           2
# 1000GB HDD          2
# 1TB STORAGE         2
# 128GB STORAGE       1
# Name: count, dtype: int64

# %%
df_laptops[df_laptops['Brand']=="Unknown"]
# Out:
#                                                                                                                                                                                                Name  \
# 137                                                                                NEC VK25 Refurbished 2-in-1 Laptop Intel Core i5-7200U, 2.7GHz, 8GB RAM, 256GB SSD, Touchscreen, 360 Convertible
# 149                                           BRAND NEW 15s Laptop PC Intel Core i5 1235U 12th Generation CPU 8GB DDR4 RAM 256GB SSD Intel Iris Xe 15.6 Inch Full HD Windows 11 Home Natural Silver
# 220                            Spectre x360 14-ef2013dx Intel Core i7 13th Gen 16GB RAM 512GB SSD 13.5 WUXGA Multi-Touch IPS Display Intel Iris Xe GPU Windows 11 High-End Laptop - Nightfall Black
# 251                                                               SONY VJPG11 Laptop - Intel Core i5-7200U 2.50GHz 4 CPUs, 8GB RAM, 256GB SSD, Windows 10 - Sleek and Powerful Performance Notebook
# 292                                                         NEC VKT13 Refurbished laptop Intel Core i5 8th gen 1.30GHz 4 CPUs Boost to 1.60GHz 8GB RAM 128GB ROM SSD 12 inch Display Windows 10 Pro
# 325                                               Refurbished LenovoThinkPad L390 Laptop Intel Core i5-8365U Processor, 8th Generation, 16GB RAM, 256GB SSD, 13.3 Inch Display, Windows 10 FREE BAG
# 337                                                                                                                                         Sony VJPG11C11N Laptop - 8GB RAM, 256GB SSD, Windows 10
# 357                                                                                             Infinix Laptop X2 Core i5 Windows 11 USBCUSB3.0HDMISD Card3.5mm Headset 8GB Ram 512GB SSD 14.1 inch
# 375                                                      REFURBISHED EliteBook 840 G3 14-inch Laptop, Intel i5 6300U 2.4GHz, 8GB DDR4 RAM, 256GB M.2 SSD Hard Drive, USB Type C, Webcam, Windows 10
# 499                                                                                             Infinix Laptop X2 Core i5 Windows 11 USBCUSB3.0HDMISD Card3.5mm Headset 8GB Ram 512GB SSD 14.1 inch
# 525                         Acer TravelMate TX50 G2 Business Laptop Intel Core i5-7200U Processor 2.50GHz, 4 Cores, 8GB RAM, 256GB SSD, 15.6 Full HD Display, Windows 10 Pro, NVIDIA GeForce 940MX.
# 572                                                                                               Refurbished GPD Pocket Mini Laptop 128GB SSD 8GB RAM 7000 mAh battery Intel Atom x7-Z8750 Laptops
# 587                                                                                                          Refurbished laptop Elitebook 840 G5 8th Gen Core I5, 8GB RAM, 256GB SSD -14 windows 11
# 592                                                                                                    650 G1 CORE I5 8GB RAM 500GB HDD 5TH GENERATION 15,.6 INCH WINDOWS 10 PRO REFURBISHED LAPTOP
# 600                                                                                                   Refurbished Acer X360 Chromebook Touchscreen 4GB RAM 32GB HDD 11.5 Laptops Computers Notebook
# 656                                                                      ThinkPad X280 Touchscreen Intel Core i5-8350U 8GB RAM 256GB SSD Refurbished Laptop 13 screen size windows 11 pro installed
# 680                                              Refurbished EliteBook 840 G3 Intel Core I5 6th Gen 14inch 8GB, 256GB SSD STORAGE - Silver Windows 10 pro 64bit OS Office activated Free laptop bag
# 787   FREE MOUSE8GB256GBHp Elitebook 840 G3 - Core i5 6th Gen - 8GB RAM - 256GB SSD- 13.3 Refurbished laptop - Windows 10 Notebook - Office 2019HP ProBook 840 G3 Laptop 33.8 cm 13.3 HD Intel Core
# 822                                                                                                   Refurbished Acer X360 Chromebook Touchscreen 4GB RAM 32GB HDD 11.5 Laptops Computers Notebook
# 844                                                                                                   Refurbished Acer X360 Chromebook Touchscreen 4GB RAM 16GB SSD 11.5 Laptops Computers Notebook
# 938                                                                                                                      SURFACE PRO 4 LAPTOP CORE i5 8gb RAM 256 SSD TOUCHSCREEN, BACKLIT KEYBORD.
# 947                                                                                                           Reburbished Laptop Probook 640 G4 8th Gen Core i5 8GB RAM 256 SSD - 14 -Silver-Win 10
# 989                                                                                                Latitude E7270 Intel Core i7 Ultrabook 12.5 Laptop i7 8GB RAM 256GB SSD TouchScreen 2.6GHz Speed
# 1008                                                      FREE MOUSE8GB500GBHp ProBook 430 G2 - Core i3 5th Gen - 8GB RAM - 500GB HDD - 13.3 Refurbished laptop - Windows 10 Notebook - Office 2019
# 1032                                                                                                                          MICROSOFT LAPTOP 2 INTEL COI5 8GB RAM MEMORY 256GB SSD 8TH GENERATION
# 1073             FREE MOUSE8GB256GBHp Elitebook 840 G3 - Core i5 6th Gen - 8GB RAM - 256GB SSD- 13.3 Refurbished laptop - Windows 10 Notebook - Office 2019HP ProBook 840 G3 Laptop 33.8 cm 13.3 HD
# 1088                                Refurbished EliteBook 840 G6 Intel Core I5 8GB RAM 256GB SSD 8th Gen 14 inch Full HD Touchscreen 1.6GHz up to 3.9GHz Quad Core Windows 11 Pro Ultra Slim Laptop
# 1161                                                             i58GB500GBMouseHp Elitebook 820 G3 Intel Core i5 6th Gen - 8GB Ram 500GB HDD - 12.5 Refurbished Laptop with Windows 10 Office 2019
# 1216                                                                                                             Refurbished EliteBook 820 G1 Core I7 500GB HDD 4GB RAM 2.1GHz 12.5 Slim Laptop Bag
# 1281                                                                                                                       Refurbished Laptop Elitebook 820 G3 6th Gen , Core i5, 8GB RAM-SSD 256GB
# 1447                                                                                                                                                              Foldable Laptop TableiPad Holder.
# 1448                   Brand new Chuwi Gemibook XPro N100 ultrabook Fast kama i5-8th Gen, 8GB256GB SSD, 14 Full HD Ultrabook with Long Battery Life Free Official Win 11 system WiFi6 Bluetooth 5.2
# 1452                                                                                                                                                              Thinkpad yoga 370 core i5 7th gen
# 1461                                                                                                                                    Installment Chuwi Gemibook Xpro link, please read and order
# 1475                                                 Refurbished LenovoThinkpad X270 Core I5 8gb Ram 256 ssd 7th Generation ,12.5 Inch Screen Size, Windows 10 With windows 10 and Office Installed
# 1479                         Brand new Chuwi CoreBook X 14 32 2k super sharp metal ultrabook 16GB512GB SSD, 14 Ultra HD Backlit keyboard Battery 8h Free Official Win 11 system WiFi6 Bluetooth 5.2
# 1492                                                                                                                                                 Latitude 7280, Core I5 8GB RAM 256GB SSD, 12.5
# 1496                                                                                                                      HOT DEALSLENOVO THINKPAD X260 COREi5 6TH GEN 8GB RAM 256GB SSD VERY CLEAN
# 1498                                                                                                                       Installment Hithium power station HeroEE 1 battery please read and order
# 1528                                                         New NEC VKT13 - Refurbished - Intel Core i5-8200Y 1.30GHz 4 CPUs, Boost to 1.60GHz - 8GB RAM - 128GB SSD - 12 Display - Windows 10 Pro
# 1544                                            Blancco S1 12 inch HD Refurbished Tablet Bundle Intel Core m3-7Y30 4GB RAM 128GB SSD Bluetooth Keyboard Mouse Gray business notebook No Touchscreen
# 1553                                                                                                              NEC VersaPro VK23TE Intel Core i5 6th Gen 2.4Ghz, 8GB RAM, 256GB SSD - Windows 11
# 1557                                                                  NEC VKT13 Refurbished Intel Core i5-8200Y 1.30GHz 4 Cores, Turbo 1.60GHz 8GB RAM 128GB SSD 12 Screen Windows 10 Pro Installed
# 1564                                                                              Refurbished EliteBook 830 G6 x360 Core I5 8GB 256GB SSD 13.3 Touchscreen FHD 8th Gen Slim UltraBook 6 Months WRTY
# 1565                                 Great Wall Gbook 14 se ultrabook Fast kama i5-8th Gen 8GB256GB SSD 14 Full HD Ultrabook with Long Battery Life Free Official Win 11 system WiFi5 Bluetooth 5.1
# 1567                                                                                                    REFURBISHED MACKBOOK AIR 2013 A1466 INTEL CORE i7 8GB RAM MEMORY 256GB SSD WITH HIGH SIERRA
# 1570                     Brand new Great Wall Gbook 14 se ultrabook Fast kama i5-8th Gen, 8GB256GB SSD, 14 Full HD Ultrabook with Long Battery Life Free Official Win 11 system WiFi5 Bluetooth 5.1
# 1580                                                                                                                         NEW YOGA 9 CORE I7 16GB RAM 1TB SSD 14NCH SCREEN SIZE TOUCH WINDOWS 11
# 1581                                                        Refurbrished Elitebook 840 G2 14.0-inch display. An Intel Core i5 4th gen 8GB DDR3 RAM 500gb hdd.windows 10 pro installed and activated
# 1605                                       Brand new Chuwi Gemibook XPro N100 ultrabook Fast kama i5-8th Gen, 8GB256GB SSD, 14 Full HD Ultrabook with Long Battery Life Free Official Win 11 system
# 1703                                                                                                                                           HOT DEALSDELL LATITUDE 6230 COREi5 4GB RAM 500GB HDD
# 1706                                                                                                                                           HOT DEALSDELL LATITUDE 6230 COREi7 4GB RAM 500GB HDD
# 1710                                                                                                                                           HOT DEALSDELL LATITUDE 5430 COREi5 4GB RAM 500GB HDD
# 1718                                                                                                                                        HOT DEALSLENOVO THINKPAD T440P COREi7 8GB RAM 500GB HDD
# 1733                                                                                                                                           HOT DEALSDELL LATITUDE 6430 COREi5 4GB RAM 500GB HDD
# 1743                                                                                                                                                 HOT DEALSDELL LATITUDE 6430 COREi7 4GB RAM 500
# 1862                                                                                                             Refurbished Probook 640 G2 Core I5 - 6th Generation - 256 SSD- 8GB RAM -14 - Black
# 1880                      Refurbished LenovoTHINKPAD X250 INTEL CORE I5 8GB RAM 500GB HDD STORAGE 4TH GENERATION , 12.5 INCH DISPLAY INSTALLED WITH WINDOWS 10 PRO,MS OFFICE 2019 NOTEBOOK COMPUTER
# 1881                                                                                                                 Refurbished Thinkpad X280 Intel Core I5 8th Gen- 8GB RAM 256GB SSD, 12.5 Black
# 1911                                                                                                                                                              Apple iMAC year 2013 core i5 81TB
# 1923                                                                                                                                                                       Yoga 380 core i7 8th gen
# 1966                                              Refurbished EliteBook 820 G3 Intel Core I5 8GB-256GB SSD 6th Gen Silver-13 Windows 10 Pro 64bit Office Activated Free wireless rechargeable mouse
# 1979                                                                                                All In One Imac 17,1 Intel Core i5 6th Gen 3.20 GHz 8 GB RAM 1 TB SSD 27 Inch Display Quad Core
# 1988                                                                                                 All In One iMac 14,3 late 2013 Intel Core i5 4th gen 2.90 GHz 16 GB 1 TB SSD 21.5 Inch Display
# 1993                                                                                                                                                       _Lenovo thinkpad E531 COI3 4GB RAM 320GB
# 1999                                                                                               Refurbished Yoga 260 Touchscreen - Core I5 8GB RAM - 256GB SSD 6th Gen-,X360 12.5, 6 Months WRTY
# 2032                                                                                                                Refurbished ProBook 11 G2, Core I3 6th Gen, 500GB HDD, 8GB RAM,12.5 TouchScreen
# 2093                      Refurbished LenovoTHINKPAD X250 INTEL CORE I5 8GB RAM 500GB HDD STORAGE 4TH GENERATION , 12.5 INCH DISPLAY INSTALLED WITH WINDOWS 10 PRO,MS OFFICE 2019 NOTEBOOK COMPUTER
# 2137                                                                         Blancco S1 12.3 HD Tablet Bundle Intel Core m3-7Y30, 4GB RAM, 128GB SSD, Bluetooth Keyboard Mouse, Gray No Touchscreen
# 2208                                                                                                                                           Refurbished PORTEGE Z30-B Corei5 5th8GB128GB SSD13.3
# 2222                                                                                                                 Refurbished Thinkpad X280 Intel Core I5 8th Gen- 8GB RAM 256GB SSD, 12.5 Black
# 2225                                                                                        Acer 11 Chromebook 11.6- 32GB 4GB Intel Celeron -Type C- Bluetooth - WiFi - Camera -Chrome OS - Refurb.
# 2226                                                           Refurbished Thinkpad X250 Intel Core I5 8 GB RAM 500 GB HDD 12.5 Black, 6 Months WRTY Windows 10 pro installed Office 2019 activated
# 2265                                                                       Refurbished Latitude 7280, 6th gen, Intel Core I5 8GB RAM 256GB SSD, 12.5 Windows 11 pro installed office 2021 activated
# 2278                                                                   EliteBook 830 G5 refurbished Intel Core i5 8th Gen 8GB RAM 256GB SSD 13.3 Inches Windows 11 Pro 64 bit Office 2021 activated
# 2285                                                                Refurbished ProBook 11 G2 TouchScreen, Core I3 6th Gen, 128GB SSD, 4GB RAM,12.5 Windows 10 Pro Installed Office 2019 activated.
# 2286                                                                            Refurbished Probook X360 11 G2 Core I5 7th Gen 8gb 256gb SSD Storage Windows 11 Pro Installed Office 2021 Activated
# 2298                                                                                                         All In One Imac 16,1 Intel Core i5 5th gen 8 GB RAM 256 SSD 1.60 GHz 21.5 inch Display
# 2301                                                                              Refurbished Probook X360 11 G1 Intel pentium 4gb 128gb SSD Storage Windows 10 Pro Installed Office 2019 Activated
# 2302                                                                                                  All In One iMac 14,1 Intel Core i5 4th gen 2.70 GHz 8 GB 1 TB SSD 21.5 Inch Display Late 2013
# 2370                                                                   RefurbishedEliteBook 8460p, Intel Core I5, 4GB RAM, 500GB HDD STORAGE 14 Inch Windows 10 pro Installed Office 2019 activated
# 2380                                                                                                  Generic Electric Double Egg Poacher Boiler Egg Steamer 14-Slot Kitchen Dining room appliances
# 2386                                                                                                                         BRAND NEWHP 14S INTEL CORE i7 12TH GENERATION 8GB RAM MEMORY 512GB SSD
# 2485                                                                                                              HOT DEALSHP PROBOOK 650G1 INTEL CORE i7 4TH GENERATION 8GB RAM 500GB HDD 15INCHES
# 2499                                                                                                                       REFURBISHED PROBOOK 11 G2 CORE I3 TOUCH SCREEN 4GB 128 GB SSD WINDOWS 10
# 2535                                                                                                                                                       Kids adventure series 6 in 1 story books
# 2600                                                                                                                      BEST DEAL ACER TX50 COI5 7TH GENERATION 8GBRAM 256GB SSD 2GB GRAPHIC CARD
# 2637                                                                                            Elitegook 840 G2-14-Core i5 5300 - 8 GB RAM - 500 GB HDD Processor Intel Core i5-5300U 2.3GHzMemory
# 2725                                                                                                                                Refurbished EliteBook 840 G3 Intel Core I5 6th Gen 8GB, 256 SSD
# 2814                                                                                                                 X Tigi Kids8 Pro Educational Kids Tablet -,,8 Display-32GB 2GB RAM-GreenPurple
# 2877                                                                                                                                                   Latitude 3550 4005u 4th Gen Core I3 4gb500gb
# 2890                                                                                                                                              28cm high quality granite coated chapatipizza pan
#
#        Price Reviews  Screen_size      RAM        ROM      Processor    Brand
# 137    16999       0          NaN      8GB  256GB SSD  Intel Core i5  Unknown
# 149    68999       0         15.6      8GB  256GB SSD  Intel Core i5  Unknown
# 220   176000       0          NaN     16GB  512GB SSD  Intel Core i7  Unknown
# 251    16999       0          NaN      8GB  256GB SSD  Intel Core i5  Unknown
# 292    16999       0         12.0      8GB      128GB  Intel Core i5  Unknown
# 325    25999       0         13.3     16GB  256GB SSD  Intel Core i5  Unknown
# 337    22040       0          NaN      8GB  256GB SSD        Unknown  Unknown
# 357    49999       0         14.1      8GB  512GB SSD  Intel Core i5  Unknown
# 375    25000       0          NaN      8GB      256GB  Intel Core i5  Unknown
# 499    48000       3         14.1      8GB  512GB SSD  Intel Core i5  Unknown
# 525    25999       0          NaN      8GB  256GB SSD  Intel Core i5  Unknown
# 572    39999       2          NaN      8GB  128GB SSD        Unknown  Unknown
# 587    30500       1          NaN      8GB  256GB SSD  Intel Core i5  Unknown
# 592    18999       8          6.0      8GB  500GB HDD  Intel Core i5  Unknown
# 600    12999       1          NaN      4GB    Unknown        Unknown  Unknown
# 656    24499       0          NaN      8GB  256GB SSD  Intel Core i5  Unknown
# 680    22499       0         14.0      8GB  256GB SSD  Intel Core i5  Unknown
# 787    28999       0          NaN      8GB  256GB SSD  Intel Core i5  Unknown
# 822    12999       2          NaN      4GB    Unknown        Unknown  Unknown
# 844    12999       0          NaN      4GB    Unknown        Unknown  Unknown
# 938    39000       0          NaN      8GB    Unknown  Intel Core i5  Unknown
# 947    23499       0          NaN      8GB    Unknown  Intel Core i5  Unknown
# 989    29999       0          NaN      8GB  256GB SSD  Intel Core i7  Unknown
# 1008   23999       0          NaN      8GB  500GB HDD  Intel Core i3  Unknown
# 1032   49999       0          NaN      8GB  256GB SSD        Unknown  Unknown
# 1073   45000       0          NaN      8GB  256GB SSD  Intel Core i5  Unknown
# 1088   36000       0         14.0      8GB  256GB SSD  Intel Core i5  Unknown
# 1161   20999       0          NaN      8GB  500GB HDD  Intel Core i5  Unknown
# 1216   21500       0          NaN      4GB  500GB HDD  Intel Core i7  Unknown
# 1281   24000       0          NaN      8GB      256GB  Intel Core i5  Unknown
# 1447    2399       1          NaN  Unknown    Unknown        Unknown  Unknown
# 1448   32222      34          NaN      8GB    Unknown  Intel Core i5  Unknown
# 1452   27500       0          NaN  Unknown    Unknown  Intel Core i5  Unknown
# 1461    6000       1          NaN  Unknown    Unknown        Unknown  Unknown
# 1475   16999       1         12.5      8GB    Unknown  Intel Core i5  Unknown
# 1479   46999       0          NaN     16GB    Unknown        Unknown  Unknown
# 1492   21500       0          NaN      8GB  256GB SSD  Intel Core i5  Unknown
# 1496   18399       0          NaN      8GB  256GB SSD        Unknown  Unknown
# 1498    5500       0          NaN  Unknown    Unknown        Unknown  Unknown
# 1528   16999       0          NaN      8GB  128GB SSD  Intel Core i5  Unknown
# 1544   16999       0         12.0      4GB  128GB SSD        Unknown  Unknown
# 1553   14249       0          NaN      8GB  256GB SSD  Intel Core i5  Unknown
# 1557   20999       0          NaN      8GB  128GB SSD  Intel Core i5  Unknown
# 1564   39999       0          NaN      8GB  256GB SSD  Intel Core i5  Unknown
# 1565   37999       0          NaN      8GB    Unknown  Intel Core i5  Unknown
# 1567   35999       0          NaN      8GB  256GB SSD  Intel Core i7  Unknown
# 1570   37999       0          NaN      8GB    Unknown  Intel Core i5  Unknown
# 1580  249000       0          NaN     16GB    1TB SSD  Intel Core i7  Unknown
# 1581   18000       0          NaN      8GB  500GB HDD  Intel Core i5  Unknown
# 1605   38999       0          NaN      8GB    Unknown  Intel Core i5  Unknown
# 1703   12999       0          NaN      4GB  500GB HDD        Unknown  Unknown
# 1706   13999       0          NaN      4GB  500GB HDD        Unknown  Unknown
# 1710   12999       0          NaN      4GB  500GB HDD        Unknown  Unknown
# 1718   19499       0          NaN      8GB  500GB HDD        Unknown  Unknown
# 1733   12999       0          NaN      4GB  500GB HDD        Unknown  Unknown
# 1743   13999       0          NaN      4GB    Unknown        Unknown  Unknown
# 1862   20999       0          NaN      8GB    Unknown  Intel Core i5  Unknown
# 1880   19599       0         12.5      8GB  500GB HDD  Intel Core i5  Unknown
# 1881   23099       0          NaN      8GB  256GB SSD  Intel Core i5  Unknown
# 1911   45000       0          NaN  Unknown    Unknown  Intel Core i5  Unknown
# 1923   42700       0          NaN  Unknown    Unknown  Intel Core i7  Unknown
# 1966   21499       0          NaN      8GB  256GB SSD  Intel Core i5  Unknown
# 1979   65250       0         27.0      8GB    1TB SSD  Intel Core i5  Unknown
# 1988   58900       0         21.5     16GB    1TB SSD  Intel Core i5  Unknown
# 1993   16000       0          NaN      4GB      320GB        Unknown  Unknown
# 1999   23499       0          NaN      8GB  256GB SSD  Intel Core i5  Unknown
# 2032   16499       0          NaN      8GB  500GB HDD  Intel Core i3  Unknown
# 2093   16999       0         12.5      8GB  500GB HDD  Intel Core i5  Unknown
# 2137   15999       0          NaN      4GB  128GB SSD        Unknown  Unknown
# 2208   20750       0          NaN  Unknown    Unknown        Unknown  Unknown
# 2222   21499       0          NaN      8GB  256GB SSD  Intel Core i5  Unknown
# 2225   10999       0          NaN     32GB    Unknown        Unknown  Unknown
# 2226   15199       0          NaN      8GB  500GB HDD  Intel Core i5  Unknown
# 2265   20499       0          NaN      8GB  256GB SSD  Intel Core i5  Unknown
# 2278   28499       0         13.3      8GB  256GB SSD  Intel Core i5  Unknown
# 2285   15999       0          NaN      4GB  128GB SSD  Intel Core i3  Unknown
# 2286   20999       0          NaN  Unknown  256GB SSD  Intel Core i5  Unknown
# 2298   54600       0         21.5      8GB    Unknown  Intel Core i5  Unknown
# 2301   13499       0          NaN  Unknown  128GB SSD        Unknown  Unknown
# 2302   51100       0         21.5      8GB    1TB SSD  Intel Core i5  Unknown
# 2370   12499       0         14.0      4GB  500GB HDD  Intel Core i5  Unknown
# 2380    1299       0          NaN  Unknown    Unknown        Unknown  Unknown
# 2386  110000       0          NaN      8GB  512GB SSD  Intel Core i7  Unknown
# 2485   20000       0         15.0      8GB  500GB HDD  Intel Core i7  Unknown
# 2499   18500       0          NaN      4GB  128GB SSD  Intel Core i3  Unknown
# 2535    1499       0          NaN  Unknown    Unknown        Unknown  Unknown
# 2600   35599       0          NaN      8GB  256GB SSD        Unknown  Unknown
# 2637   19000       0          NaN      8GB  500GB HDD  Intel Core i5  Unknown
# 2725   26676       0          NaN      8GB    Unknown  Intel Core i5  Unknown
# 2814   18000       0          NaN      2GB    Unknown        Unknown  Unknown
# 2877   19673       0          NaN  Unknown    Unknown  Intel Core i3  Unknown
# 2890    4734       0          NaN  Unknown    Unknown        Unknown  Unknown

# %%
#Remove commas and any text from Price column
df_laptops["Price"] = df_laptops['Price'].str.replace(r'[^\d]', '', regex=True)


#Remove brackets from Reviews column
df_laptops['Reviews'] = df_laptops['Reviews'].str.extract(r'(\d+)')
df_laptops.sample(20)
# Out:
#                                                                                                                                                                                                    Name  \
# 996                                 i58GB512GB14Free Mouse HP Elitebook 1040 G3 6th Intel Core i5 8GB 512GB SSD 14 FHD Display Laptop Backlit Windows 11 intel HD Graphics Bluetooth Refurbished Laptop
# 2321                                                                                                       REFURBISHED DELL LATITUDE 7390 INTEL CORE i5 8GB RAM MEMORY 512GB SSD 13.5INCHES BLACK COLOR
# 735                                  i58GB256GB SSDFree MouseRefurbished HP Probook 640 G1 Laptop Intel Core i5 8GB RAM 256GB SSD ROM 14 Windows 11 6 months warranty Notebook Bluetooth Webcam Laptops
# 2066                                                                                                                                                                Hp 830 g5 corei5 8gb 256ssd 8th Gen
# 97                                                              Refurbished Laptop Lenovo Thinkpad T430 Intel Core i5 3th Gen 4GB320GB12.5 Windows 10 Refurbished Lenovo Laptops Notebook Black 12 inch
# 2221                                            Dell Latitude E7240 Intel Core i5 2.1GHz 8GB 128GB SSD 12.5 GHz Intel Core i5-4300U 1.9ghz Processor 4GB DDR3 memory. 128GB Solid State Drive 12.5-inch
# 1482                                          Hp Elite x2 1012 G2 2IN1 Intel core i5 7th GEN 8GB RAM 256 GB SSD BACKLIT KEYBOARD DETACHABLE KEYBOARD TOUCHSCREEN 12.5 INCHES TYPE C CHARGER THUNDERBOLT
# 127                                                 Refurbished Dell Latitude E7440 Intel Core i5 5th Generation 8GB RAM 500 GB HDD Storage 14 Inches HD Display Refurbished Laptops Notebook Computers
# 2307                                            Dell Latitude E7240 Intel Core i5 2.1GHz 8GB 256GB SSD 12.5 GHz Intel Core i5-4300U 1.9ghz Processor 4GB DDR3 memory. 128GB Solid State Drive 12.5-inch
# 1428                                                                                Refurbished HP X360 Chromebook Touchscreen 4GB RAM 32GB Storage Intel Celeron N4020 11.5 Laptops Computers Notebook
# 2661                                                                                                         HP Refurbished EliteBook 840 G1, 14 - Intel Core I5, 500GB HDD, 4GB RAM - Win10 Trial, BLK
# 307                                                             HP Probook 440 G5 Core i5 8th Generation, 16GB RAM 256GB SSD, 14 Inches Quad Core, windows 11 pro, HDMI, Notebook PC Refurbished Laptop
# 2489                            WINDOWS 11 PRO ACTIVATED Office 2021Activated ,Lenovo Refurbished Yoga 11e 8GB 256GB SSD-x360 Touch Screen- Intel Celeron WINDOWS 11 PRO ACTIVATED FREE WIRELESS MOUSE.
# 697                                                                                         HP REVOLVE ELITEBOOK 810 G3 CORE I7 8GB RAM 256GB SSD,REFURBISHED LAPTOP, 5TH GENERATION TOUCHSCREEN laptop
# 819                                                                                    HP ELITEBOOK FOLIO 9470 CORE I5 8GB RAM 500GB HDD,14 INCH ,5TH GEBERATION ,REFURBISHED LAPTOP,SILVER, WINDOWS 11
# 256   Hp ProBook X360 11 G2 EE Core i5 7th Gen 8GB RAM 256GB SSD 11.6 Inches HD Touchscreen 1.2GHz up to 3.2GHz Dual Core Processor, 2 in 1 Convertible Slim Refurbished Laptop with 6 months warranty.
# 1003                                                                                                      HP ProBook 430 G6 Core I5 8th Gen 8GB 256GB SSD 13.3 Inch UltraBook Refurbished laptop Laptop
# 2327                                       8GB RAM, 500GB Hard disk, Lenovo X131E, 12.5 Screen Display, Windows 11 PRO Activated, Office Basic software Installed Free Bag Charger Free wireless Mouse.
# 755                                                              HP PROBOOK 650 G1 CORE I5 8GB RAM 500GB HDD 5TH GENERATION 15,.6 INCH WINDOWS 10 PRO FREE MOUSE FULL KEYBOARD LAPTOPREFURBISHED LAPTOP
# 2226                                                               Refurbished Thinkpad X250 Intel Core I5 8 GB RAM 500 GB HDD 12.5 Black, 6 Months WRTY Windows 10 pro installed Office 2019 activated
#
#       Price Reviews  Screen_size      RAM        ROM      Processor    Brand
# 996   27999       0          NaN      8GB  512GB SSD  Intel Core i5       HP
# 2321  30000       0         13.5      8GB  512GB SSD  Intel Core i5     DELL
# 735   21999       0          NaN      8GB  256GB SSD  Intel Core i5       HP
# 2066  35000       0          NaN  Unknown    Unknown        Unknown       Hp
# 97    13299       2         12.0      4GB    Unknown  Intel Core i5   Lenovo
# 2221  19999       0          NaN      8GB  128GB SSD  Intel Core i5     Dell
# 1482  39700       1         12.5      8GB  256GB SSD  Intel Core i5       Hp
# 127   16499       0         14.0      8GB  500GB HDD  Intel Core i5     Dell
# 2307  36000       0          NaN      8GB  256GB SSD  Intel Core i5     Dell
# 1428  11999       3          NaN      4GB    Unknown        Unknown       HP
# 2661  27000       0          NaN      4GB  500GB HDD  Intel Core i5       HP
# 307   35999       0         14.0     16GB  256GB SSD  Intel Core i5       HP
# 2489  22500       0          NaN      8GB  256GB SSD        Unknown   Lenovo
# 697   37000       0          NaN      8GB  256GB SSD  Intel Core i7       HP
# 819   18999      10         14.0      8GB  500GB HDD  Intel Core i5       HP
# 256   22000       0         11.6      8GB  256GB SSD  Intel Core i5       Hp
# 1003  24999       0         13.3      8GB  256GB SSD  Intel Core i5       HP
# 2327  16999       0          NaN      8GB      500GB        Unknown   Lenovo
# 755   20999       0          6.0      8GB  500GB HDD  Intel Core i5       HP
# 2226  15199       0          NaN      8GB  500GB HDD  Intel Core i5  Unknown

# %%
df_laptops['Processor'].value_counts()
# Out:
# Processor
# Intel Core i5    1753
# Unknown           696
# Intel Core i7     399
# Intel Core i3      64
# Intel Core i9       3
# Name: count, dtype: int64

# %%
# Save to CSV
#df_laptops.to_csv('laptops_clean.csv', index=True)
